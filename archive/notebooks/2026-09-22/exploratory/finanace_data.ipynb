# %%
import os

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine, text

from apemap.utils import get_wikipedia_entity_id

load_dotenv("../../.env")

engine = create_engine(
    f"postgresql+psycopg://{os.environ.get('DATABASE_USERNAME')}:{os.environ.get('DATABASE_PASSWORD')}@localhost:5432/{os.environ.get('DATABASE_NAME')}")

schools_to_fetch = pd.read_sql("SELECT DISTINCT acara_id from education_acara WHERE acara_id not in (SELECT acara_id from acara_education_finances) AND acara_id not in (SELECT acara_id from acara_finance_missing) ", engine)
schools_to_fetch
# Out:
#    acara_id
# 0     40334
# 1     40618
# 2     43838
# 3     45936

# %%
from utils import get_finances, MissingSchool
missing_schools = pd.DataFrame(columns=["acara_id"])
finances = pd.DataFrame()
for row in schools_to_fetch.itertuples():
    try:
        df = get_finances(row.acara_id)
        if finances.empty:
            finances = df
        else:
          # append df to finances
            finances = pd.concat([finances, df])
    except MissingSchool as e:
        missing_schools = pd.concat([missing_schools, pd.DataFrame.from_records([{"acara_id": int(row.acara_id)}])])
    except Exception as e:
        pass  # Database writes are disabled in this read-only notebook.
# [MUTATION NEUTRALIZED]         finances.drop_duplicates().to_sql("education_acara_finances", engine, if_exists="append", index=True, index_label="acara_id")
        raise e
# Out:
# Getting finances for 40334 - 2021
# Getting finances for 40618 - 2021
# Getting finances for 43838 - 2021
# Getting finances for 45936 - 2021

# %% [markdown]
# # No data available for Hobart City high School

# %%
# [MUTATION NEUTRALIZED] finances.drop_duplicates().to_sql("education_acara_finances", engine, if_exists="append", index=True, index_label="acara_id")
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/psycopg/cursor.py:723, in Cursor.execute(self, query, params, prepare, binary)
#     722 except e.Error as ex:
# --> 723     raise ex.with_traceback(None)
#     724 return self
#
# DuplicateTable: relation "ix_education_acara_finances_acara_id" already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 finances.drop_duplicates().to_sql("education_acara_finances", engine, if_exists="append", index=True, index_label="acara_id")
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/pandas/io/sql.py:767, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     762     raise NotImplementedError(
#     763         "'frame' argument should be either a Series or a DataFrame"
#     764     )
#     766 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 767     return pandas_sql.to_sql(
#     768         frame,
#     769         name,
#     770         if_exists=if_exists,
#     771         index=index,
#     772         index_label=index_label,
#     773         schema=schema,
#     774         chunksize=chunksize,
#     775         dtype=dtype,
#     776         method=method,
#     777         engine=engine,
#     778         **engine_kwargs,
#     779     )
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/pandas/io/sql.py:1908, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1858 """
#    1859 Write records stored in a DataFrame to a SQL database.
#    1860
#    (...)
#    1904     Any additional kwargs are passed to the engine.
#    1905 """
#    1906 sql_engine = get_engine(engine)
# -> 1908 table = self.prep_table(
#    1909     frame=frame,
#    1910     name=name,
#    1911     if_exists=if_exists,
#    1912     index=index,
#    1913     index_label=index_label,
#    1914     schema=schema,
#    1915     dtype=dtype,
#    1916 )
#    1918 total_inserted = sql_engine.insert_records(
#    1919     table=table,
#    1920     con=self.con,
#    (...)
#    1927     **engine_kwargs,
#    1928 )
#    1930 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/pandas/io/sql.py:1812, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1800             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1802 table = SQLTable(
#    1803     name,
#    1804     self,
#    (...)
#    1810     dtype=dtype,
#    1811 )
# -> 1812 table.create()
#    1813 return table
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/pandas/io/sql.py:912, in SQLTable.create(self)
#     910         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     911 else:
# --> 912     self._execute_create()
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/pandas/io/sql.py:898, in SQLTable._execute_create(self)
#     896 self.table = self.table.to_metadata(self.pd_sql.meta)
#     897 with self.pd_sql.run_transaction():
# --> 898     self.table.create(bind=self.pd_sql.con)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/sql/schema.py:1149, in Table.create(self, bind, checkfirst)
#    1137 def create(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1138     """Issue a ``CREATE`` statement for this
#    1139     :class:`_schema.Table`, using the given
#    1140     :class:`.Connection` or :class:`.Engine`
#    (...)
#    1146
#    1147     """
# -> 1149     bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2430, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2418 def _run_ddl_visitor(
#    2419     self,
#    2420     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2421     element: SchemaItem,
#    2422     **kwargs: Any,
#    2423 ) -> None:
#    2424     """run a DDL visitor.
#    2425
#    2426     This method is only here so that the MockConnection can change the
#    2427     options given to the visitor so that "checkfirst" is skipped.
#    2428
#    2429     """
# -> 2430     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/sql/visitors.py:670, in ExternalTraversal.traverse_single(self, obj, **kw)
#     668 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     669 if meth:
# --> 670     return meth(obj, **kw)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/sql/ddl.py:967, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     965 if hasattr(table, "indexes"):
#     966     for index in table.indexes:
# --> 967         self.traverse_single(index, create_ok=True)
#     969 if (
#     970     self.dialect.supports_comments
#     971     and not self.dialect.inline_comments
#     972 ):
#     973     if table.comment is not None:
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/sql/visitors.py:670, in ExternalTraversal.traverse_single(self, obj, **kw)
#     668 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     669 if meth:
# --> 670     return meth(obj, **kw)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/sql/ddl.py:1004, in SchemaGenerator.visit_index(self, index, create_ok)
#    1002     return
#    1003 with self.with_ddl_events(index):
# -> 1004     CreateIndex(index)._invoke_with(self.connection)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/sql/ddl.py:315, in ExecutableDDLElement._invoke_with(self, bind)
#     313 def _invoke_with(self, bind):
#     314     if self._should_execute(self.target, bind):
# --> 315         return bind.execute(self)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1414, in Connection.execute(self, statement, parameters, execution_options)
#    1412     raise exc.ObjectNotExecutableError(statement) from err
#    1413 else:
# -> 1414     return meth(
#    1415         self,
#    1416         distilled_parameters,
#    1417         execution_options or NO_OPTIONS,
#    1418     )
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/sql/ddl.py:181, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     178 def _execute_on_connection(
#     179     self, connection, distilled_params, execution_options
#     180 ):
# --> 181     return connection._execute_ddl(
#     182         self, distilled_params, execution_options
#     183     )
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1526, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1521 dialect = self.dialect
#    1523 compiled = ddl.compile(
#    1524     dialect=dialect, schema_translate_map=schema_translate_map
#    1525 )
# -> 1526 ret = self._execute_context(
#    1527     dialect,
#    1528     dialect.execution_ctx_cls._init_ddl,
#    1529     compiled,
#    1530     None,
#    1531     execution_options,
#    1532     compiled,
#    1533 )
#    1534 if self._has_events or self.engine._has_events:
#    1535     self.dispatch.after_execute(
#    1536         self,
#    1537         ddl,
#    (...)
#    1541         ret,
#    1542     )
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1842, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1837     return self._exec_insertmany_context(
#    1838         dialect,
#    1839         context,
#    1840     )
#    1841 else:
# -> 1842     return self._exec_single_context(
#    1843         dialect, context, statement, parameters
#    1844     )
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2326, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2324 elif should_wrap:
#    2325     assert sqlalchemy_exception is not None
# -> 2326     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2327 else:
#    2328     assert exc_info[1] is not None
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/sqlalchemy/engine/default.py:748, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     747 def do_execute(self, cursor, statement, parameters, context=None):
# --> 748     cursor.execute(statement, parameters)
#
# File ~/.cache/pypoetry/virtualenvs/pollypedagogymap-qWdi3x2k-py3.10/lib/python3.10/site-packages/psycopg/cursor.py:723, in Cursor.execute(self, query, params, prepare, binary)
#     719         self._conn.wait(
#     720             self._execute_gen(query, params, prepare=prepare, binary=binary)
#     721         )
#     722 except e.Error as ex:
# --> 723     raise ex.with_traceback(None)
#     724 return self
#
# ProgrammingError: (psycopg.errors.DuplicateTable) relation "ix_education_acara_finances_acara_id" already exists
# [SQL: CREATE INDEX ix_education_acara_finances_acara_id ON education_acara_finances (acara_id)]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# [MUTATION NEUTRALIZED] finances.reset_index().rename(columns={"school_id": "acara_id"}).to_sql("education_acara_finances", engine, if_exists="append")
# Out:
# -1
