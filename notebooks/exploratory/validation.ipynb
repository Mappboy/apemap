# %% [markdown]
# Data validation to make sure our data is clean, and all the data is in the correct format.

# %%
# Compare parliament 46 to smh careers
import os

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv("../../.env")

engine = create_engine(
    f"postgresql+psycopg://{os.environ.get('DATABASE_USERNAME')}:{os.environ.get('DATABASE_PASSWORD')}@localhost:5432/{os.environ.get('DATABASE_NAME')}")

# %%
# compare high_school in members to high_school in smh_careers
members = pd.read_sql("SELECT * FROM members", engine)
smh_members = pd.read_sql("SELECT * FROM smh_careers", engine)
members.head()
# Out:
#     id  orig_id orig_table            member         district  is_senator
# 0   49       24         47      Anne Stanley          Werriwa       False  \
# 1  174      178         47   Rebekha Sharkie             Mayo       False
# 2   62      156         47      Monique Ryan          Kooyong       False
# 3   65      112         47   Kerrynne Liddle  South Australia        True
# 4  185       91         47  Jenny McAllister  New South Wales        True
#
#    is_representative  graduated       start
# 0               True       True  2016-07-02  \
# 1               True       True  2018-07-28
# 2               True       True  2022-05-21
# 3              False       True  2022-07-01
# 4              False       True  2015-05-06
#
#                                    wiki_link         dob   mp_id  party_id
# 0   http://www.wikidata.org/entity/Q25768264  1961-10-06  265990        11  \
# 1   http://www.wikidata.org/entity/Q25324881  1972-08-24  265980        17
# 2   http://www.wikidata.org/entity/Q42696287  1967-01-20  297660        16
# 3  http://www.wikidata.org/entity/Q112581963  1967-10-07  300644        42
# 4   http://www.wikidata.org/entity/Q16732210  1973-07-04  121628        11
#
#     house     high_school    preferred_name              aph_name
# 0   house          Public              None          Anne Stanley
# 1   house            None              None       Rebekha Sharkie
# 2   house  Non-government              None          Monique Ryan
# 3  senate          Public              None       Kerrynne Liddle
# 4  senate          Public  Jenny Mcallister  Jennifer  Mcallister

# %%
smh_members.head()
# Out:
#    fid  rowid  index           member    party chamber electorate state
# 0   29     29     28    Julie Collins    Labor   House   Franklin   Tas  \
# 1   48     48     47  Steve Georganas    Labor   House   Adelaide    SA
# 2   82     82     81      Nola Marino  Liberal   House    Forrest    WA
# 3  136    136    135   Bert van Manen  Liberal   House      Forde   Qld
# 4  162    162    161         Kim Carr    Labor  Senate        Vic   Vic
#
#   high school                 undergraduate                  postgraduate
# 0        None                          None                          None  \
# 1      Public                          None                          None
# 2      Public                          None                          None
# 3      Public                          None                          None
# 4      Public  BA (University of Melbourne)  MA (University of Melbourne)
#
#                                            career government  replied? sex
# 0                                  Public Service       None       NaN   F  \
# 1  Blue-collar or service, Business or Management       None       NaN   M
# 2  Blue-collar or service, Business or Management       None       NaN   F
# 3                          Business or Management       None       NaN   M
# 4                                       Education       None       NaN   M
#
#    birth year
# 0        1971
# 1        1959
# 2        1967
# 3        1954
# 4        1955

# %%
smh_members.count()
# Out:
# fid              227
# rowid            227
# index            227
# member           227
# party            227
# chamber          227
# electorate       227
# state            227
# high school      223
# undergraduate    173
# postgraduate      67
# career           220
# government        51
# replied?         125
# sex              227
# birth year       227
# dtype: int64

# %%
smh_members["member"] = smh_members["member"].str.strip()
combined_init = pd.merge(members, smh_members, how="inner", left_on="member", right_on="member", suffixes=("_members", "_smh"))
combined_alias = pd.merge(members, smh_members, how="inner", left_on="preferred_name", right_on="member", suffixes=("_members", "_smh"))
combined_aph = pd.merge(members, smh_members, how="inner", left_on="aph_name", right_on="member", suffixes=("_members", "_smh"))
combined = pd.concat([combined_init, combined_alias, combined_aph])
combined.member.fillna(combined.member_smh, inplace=True)
combined.drop_duplicates(["member"], inplace=True)
combined[ combined["high_school"] != combined["high school"]]
# Out:
#       id  orig_id orig_table              member           district
# 1    174      178         47     Rebekha Sharkie               Mayo  \
# 2    185       91         47    Jenny McAllister    New South Wales
# 10    86        3         47          Alex Antic    South Australia
# 12    71       82         47       Jacqui Lambie           Tasmania
# 27    14       33         47          Bob Katter            Kennedy
# 32   133      170         47         Perin Davey    New South Wales
# 33   123      105         47       Karen Andrews          McPherson
# 35    64        9         46            Kim Carr           Victoria
# 36   278       42         47       Catryna Bilyk           Tasmania
# 38    34      137         47        Mark Dreyfus             Isaacs
# 39   118       44         46          Scott Ryan           Victoria
# 46   119       10         46       Nick Champion             Spence
# 53   188       34         46          Gladys Liu           Chisholm
# 54   234       49         47       Daniel Mulino             Fraser
# 59   152      123         47        Llew O'Brien           Wide Bay
# 66   158      215         47          Tony Burke             Watson
# 87    89       66         47        Emma McBride             Dobell
# 94   160      132         47      Marielle Smith    South Australia
# 96   207       98         47  Jordon Steele-John  Western Australia
# 100   82      174         47  Peter Whish-Wilson           Tasmania
# 101  159       55         46          Tim Wilson          Goldstein
# 103  265       56         46           Ken Wyatt            Hasluck
# 104    5       48         47           Dan Tehan             Wannon
# 109  239       33         46       Andrew Laming             Bowman
# 113  171       54         46          Lucy Wicks          Robertson
# 114  168      100         47         Josh Wilson          Fremantle
# 118  208       55         47   David Littleproud            Maranoa
# 125   47      130         47     Malcolm Roberts         Queensland
# 126  276      181         47         Rick Wilson           O'Connor
# 133  282      103         47       Julie Collins           Franklin
# 141  209        4         47          Alex Hawke           Mitchell
# 149   91      158         47          Nick McKim           Tasmania
# 150  187        2         46      John Alexander          Bennelong
# 170  180      161         47        Pat Conaghan             Cowper
# 173  220       26         47        Anne Webster             Mallee
# 178  128        1         46          Eric Abetz           Tasmania
# 182  161       79         47       Hollie Hughes    New South Wales
# 186  184       47         46      Rachel Siewert  Western Australia
# 193  242      212         47         Terry Young            Longman
# 198   48      126         47        Luke Gosling            Solomon
# 203  267      192         47     Sarah Henderson           Victoria
# 205  163       37         47    Bridget McKenzie           Victoria
# 206  151      146         47       Melissa Price             Durack
# 210   84       31         46   Kristina Keneally    New South Wales
# 18   269       40         46          Ken O'Dowd              Flynn
#
#      is_senator  is_representative  graduated       start
# 1         False               True       True  2018-07-28  \
# 2          True              False       True  2015-05-06
# 10         True              False       True  2019-07-01
# 12         True              False      False  2019-07-01
# 27        False               True       True  1993-03-13
# 32         True              False       True  2019-07-01
# 33        False               True       True  2010-08-21
# 35         True              False       True  1993-04-28
# 36         True              False       True  2008-07-01
# 38        False               True       True  2007-11-24
# 39         True              False       True  2008-07-01
# 46        False               True       True  2007-11-24
# 53        False               True       True  2019-05-18
# 54        False               True       True  2019-05-18
# 59        False               True      False  2016-07-02
# 66        False               True       True  2004-10-09
# 87        False               True       True  2016-07-02
# 94         True              False       True  2019-07-01
# 96         True              False       True  2017-11-10
# 100        True              False       True  2012-06-20
# 101       False               True       True  2016-07-02
# 103       False               True       True  2010-08-21
# 104       False               True       True  2010-08-21
# 109       False               True       True  2004-10-09
# 113       False               True       True  2013-09-07
# 114       False               True       True  2018-07-28
# 118       False               True       True  2016-07-02
# 125        True              False       True  2019-07-01
# 126       False               True       True  2013-09-07
# 133       False               True      False  2007-11-24
# 141       False               True       True  2007-11-24
# 149        True              False       True  2015-08-19
# 150       False               True       True  2010-08-21
# 170       False               True       True  2019-05-18
# 173       False               True       True  2019-05-18
# 178        True              False       True  1994-02-22
# 182        True              False       True  2019-07-01
# 186        True              False       True  2005-07-01
# 193       False               True      False  2019-05-18
# 198       False               True       True  2016-07-02
# 203        True              False       True  2019-09-11
# 205        True              False       True  2011-07-01
# 206       False               True       True  2013-09-07
# 210        True              False       True  2018-02-14
# 18        False               True       True  2010-08-21
#
#                                     wiki_link  ...             high school
# 1    http://www.wikidata.org/entity/Q25324881  ...          Non-government  \
# 2    http://www.wikidata.org/entity/Q16732210  ...  Non-government, Public
# 10   http://www.wikidata.org/entity/Q63520981  ...          Non-government
# 12   http://www.wikidata.org/entity/Q16731201  ...                    None
# 27    http://www.wikidata.org/entity/Q4932983  ...          Non-government
# 32   http://www.wikidata.org/entity/Q64685099  ...  Non-government, Public
# 33    http://www.wikidata.org/entity/Q6369482  ...  Non-government, Public
# 35    http://www.wikidata.org/entity/Q1639334  ...                  Public
# 36    http://www.wikidata.org/entity/Q5053981  ...                  Public
# 38    http://www.wikidata.org/entity/Q6767411  ...          Non-government
# 39    http://www.wikidata.org/entity/Q7437178  ...          Non-government
# 46    http://www.wikidata.org/entity/Q7026894  ...                  Public
# 53   http://www.wikidata.org/entity/Q63979376  ...           International
# 54   http://www.wikidata.org/entity/Q19518195  ...  Non-government, Public
# 59   http://www.wikidata.org/entity/Q25756234  ...                    None
# 66    http://www.wikidata.org/entity/Q1449483  ...          Non-government
# 87   http://www.wikidata.org/entity/Q25844494  ...          Non-government
# 94   http://www.wikidata.org/entity/Q63531157  ...  Non-government, Public
# 96   http://www.wikidata.org/entity/Q33139188  ...           Home-schooled
# 100   http://www.wikidata.org/entity/Q7177677  ...  Non-government, Public
# 101   http://www.wikidata.org/entity/Q7807613  ...          Non-government
# 103                                      None  ...  Non-government, Public
# 104   http://www.wikidata.org/entity/Q5214486  ...  Non-government, Public
# 109   http://www.wikidata.org/entity/Q4757684  ...          Non-government
# 113  http://www.wikidata.org/entity/Q16875919  ...          Non-government
# 114  http://www.wikidata.org/entity/Q27435061  ...                  Public
# 118  http://www.wikidata.org/entity/Q25756209  ...  Non-government, Public
# 125  http://www.wikidata.org/entity/Q26848575  ...  Non-government, Public
# 126  http://www.wikidata.org/entity/Q16196773  ...  Non-government, Public
# 133   http://www.wikidata.org/entity/Q6308091  ...                    None
# 141   http://www.wikidata.org/entity/Q4717151  ...  Non-government, Public
# 149  http://www.wikidata.org/entity/Q14201517  ...                  Public
# 150    http://www.wikidata.org/entity/Q364407  ...          Non-government
# 170  http://www.wikidata.org/entity/Q63993700  ...          Non-government
# 173  http://www.wikidata.org/entity/Q64216519  ...                  Public
# 178    http://www.wikidata.org/entity/Q964840  ...                  Public
# 182  http://www.wikidata.org/entity/Q60734047  ...          Non-government
# 186   http://www.wikidata.org/entity/Q2125232  ...                  Public
# 193  http://www.wikidata.org/entity/Q64216512  ...                    None
# 198  http://www.wikidata.org/entity/Q25288450  ...  Non-government, Public
# 203   http://www.wikidata.org/entity/Q7422387  ...          Non-government
# 205   http://www.wikidata.org/entity/Q4966734  ...          Non-government
# 206  http://www.wikidata.org/entity/Q16195275  ...          Non-government
# 210    http://www.wikidata.org/entity/Q442238  ...           International
# 18                                       None  ...  Non-government, Public
#
#                                          undergraduate
# 1                             BA (Flinders University)  \
# 2                            BA (University of Sydney)
# 10   BA (University of Adelaide), LLB (University o...
# 12                                                None
# 27                                                None
# 32                                                None
# 33          BEng (Queensland University of Technology)
# 35                        BA (University of Melbourne)
# 36                                                None
# 38   BA (University of Melbourne), LLB (University ...
# 39                        BA (University of Melbourne)
# 46                  BA (University of South Australia)
# 53                        BAppSc (La Trobe University)
# 54   BA (Australian National University), LLB (Aust...
# 59                                                None
# 66   LLB (University of Sydney), BA (University of ...
# 87                       BPharm (University of Sydney)
# 94                 BA (Australian National University)
# 96                                                None
# 100                 BA (University of New South Wales)
# 101                             BA (Monash University)
# 103    BEd (Churchlands College of Advanced Education)
# 104                       BA (University of Melbourne)
# 109                    MBBS (University of Queensland)
# 113                          BA (University of Sydney)
# 114               BA (University of Western Australia)
# 118                                               None
# 125                    BEng (University of Queensland)
# 126                           Bbus (Curtin University)
# 133                                               None
# 141                          BA (University of Sydney)
# 149                                               None
# 150                                               None
# 170                    LLB (University of New England)
# 173  BSocWrk (La Trobe University), BA (La Trobe Un...
# 178  BA (University of Tasmania), LLB (University o...
# 182                      BA (Charles Sturt University)
# 186              BSc (University of Western Australia)
# 193                                               None
# 198                         BA (UNSW Canberra at ADFA)
# 203                            LLB (Monash University)
# 205  BT (Deakin University), BAppSc (Deakin Univers...
# 206                 LLB (London South Bank University)
# 210                          BA (University of Dayton)
# 18                                                None
#
#                                           postgraduate
# 1                                                 None  \
# 2                                                 None
# 10                                                None
# 12                                                None
# 27                                                None
# 32                                                None
# 33                                                None
# 35                        MA (University of Melbourne)
# 36                                                None
# 38                                                None
# 39                                                None
# 46                                                None
# 53                                                None
# 54            MEcon (University of Sydney), PhD (Yale)
# 59                                                None
# 66                                                None
# 87                                                None
# 94                    MSc (London School of Economics)
# 96                                                None
# 100              MEc (University of Western Australia)
# 101                       MDip&Tde (Monash University)
# 103                                               None
# 104  MIR (Kent University), MForAffTde (Monash Univ...
# 109  DRCOG (Royal College of Obstetricians and Gyna...
# 113                                               None
# 114                       MA (University of Melbourne)
# 118                                               None
# 125                        MBA (University of Chicago)
# 126                                               None
# 133                                               None
# 141             MPubAffairs&Gov (University of Sydney)
# 149                                               None
# 150                                               None
# 170                                               None
# 173               PhD (Australian National University)
# 178                                               None
# 182                 MPol&PubPol (Macquarie University)
# 186                                               None
# 193                                               None
# 198                                               None
# 203                                               None
# 205                                               None
# 206                                               None
# 210                          MA (University of Dayton)
# 18                                                None
#
#                                                 career
# 1              Private Law, Nonprofits, Public Service  \
# 2               Public Service, Business or Management
# 10                                         Private Law
# 12                                            Military
# 27   Blue-collar or service, Business or Management...
# 32             Media, Business or Management, Military
# 33   Science or Engineering, Lobbying or Activism, ...
# 35                                           Education
# 36   Blue-collar or service, Business or Management...
# 38                             Nonprofits, Private Law
# 39   Academia, Public Service, Business or Manageme...
# 46                                              Unions
# 53   Public Service, Business or Management, Medici...
# 54    Public Service, Academia, Business or Management
# 59             Blue-collar or service, Law Enforcement
# 66   Blue-collar or service, Business or Management...
# 87         Medicine and Health, Business or Management
# 94              Public Service, Business or Management
# 96                                                None
# 100  Business or Management, Academia, Blue-collar ...
# 101  Unions, Academia, Business or Management, Lobb...
# 103  Education, Public Service, Business or Management
# 104      Farming, Public Service, Lobbying or Activism
# 109  Medicine and Health, Blue-collar or service, N...
# 113                  Education, Business or Management
# 114                       Private Law, Academia, Media
# 118                    Farming, Business or Management
# 125  Farming, Blue-collar or service, Science or En...
# 126                      Farming, Lobbying or Activism
# 133                                     Public Service
# 141                   Business or Management, Military
# 149  Farming, Blue-collar or service, Business or M...
# 150              Sports, Business or Management, Media
# 170                       Law Enforcement, Private Law
# 173  Arts, Blue-collar or service, Education, Busin...
# 178                                        Private Law
# 182  Lobbying or Activism, Nonprofits, Business or ...
# 186               Public Service, Lobbying or Activism
# 193     Blue-collar or service, Business or Management
# 198                               Nonprofits, Military
# 203         Media, Private Law, Business or Management
# 205                                Education, Academia
# 206    Nonprofits, Private Law, Business or Management
# 210             Education, Academia, Nonprofits, Media
# 18                              Business or Management
#
#                                           government replied? sex  birth year
# 1                                               None      1.0   F        1975  \
# 2                                               None      NaN   F        1982
# 10                                  Local government      1.0   M        1974
# 12                                              None      1.0   F        1971
# 27                     State or Territory government      NaN   M        1945
# 32                                              None      1.0   F        1972
# 33                                              None      NaN   F        1960
# 35                                              None      NaN   M        1955
# 36                                              None      1.0   F        1959
# 38                                              None      1.0   M        1956
# 39                                              None      NaN   M        1969
# 46                                              None      NaN   M        1972
# 53                                              None      1.0   F        1964
# 54   State or Territory government, Local government      1.0   M        1973
# 59                                              None      NaN   M        1972
# 66                     State or Territory government      1.0   M        1969
# 87                                  Local government      1.0   F        1970
# 94                                              None      1.0   F        1986
# 96                                              None      1.0   M        1974
# 100                                             None      1.0   M        1968
# 101                                             None      1.0   M        1980
# 103                                             None      NaN   M        1952
# 104                                             None      NaN   M        1963
# 109                                             None      1.0   M        1966
# 113                                             None      NaN   F        1973
# 114                                 Local government      1.0   M        1972
# 118                                             None      NaN   M        1976
# 125                                             None      NaN   M        1971
# 126                                             None      NaN   M        1966
# 133                                             None      NaN   F        1971
# 141                                             None      NaN   M        1977
# 149                    State or Territory government      1.0   M        1966
# 150                                             None      1.0   M        1951
# 170                                 Local government      NaN   M        1971
# 173                                             None      1.0   F        1959
# 178                                             None      1.0   M        1958
# 182                                             None      1.0   F        1975
# 186                                             None      NaN   F        1985
# 193                                             None      NaN   M        1968
# 198                                             None      1.0   M        1971
# 203                                             None      1.0   F        1964
# 205                                             None      1.0   F        1965
# 206                                             None      1.0   F        1956
# 210                    State or Territory government      NaN   F        1968
# 18                                              None      NaN   M        1980
#
#      member_members  member_smh
# 1               NaN         NaN
# 2               NaN         NaN
# 10              NaN         NaN
# 12              NaN         NaN
# 27              NaN         NaN
# 32              NaN         NaN
# 33              NaN         NaN
# 35              NaN         NaN
# 36              NaN         NaN
# 38              NaN         NaN
# 39              NaN         NaN
# 46              NaN         NaN
# 53              NaN         NaN
# 54              NaN         NaN
# 59              NaN         NaN
# 66              NaN         NaN
# 87              NaN         NaN
# 94              NaN         NaN
# 96              NaN         NaN
# 100             NaN         NaN
# 101             NaN         NaN
# 103             NaN         NaN
# 104             NaN         NaN
# 109             NaN         NaN
# 113             NaN         NaN
# 114             NaN         NaN
# 118             NaN         NaN
# 125             NaN         NaN
# 126             NaN         NaN
# 133             NaN         NaN
# 141             NaN         NaN
# 149             NaN         NaN
# 150             NaN         NaN
# 170             NaN         NaN
# 173             NaN         NaN
# 178             NaN         NaN
# 182             NaN         NaN
# 186             NaN         NaN
# 193             NaN         NaN
# 198             NaN         NaN
# 203             NaN         NaN
# 205             NaN         NaN
# 206             NaN         NaN
# 210             NaN         NaN
# 18   Kenneth O'dowd  Ken O'Dowd
#
# [45 rows x 34 columns]

# %%
combined
# Out:
#       id  orig_id orig_table            member         district  is_senator
# 0     54       27         47  Anthony Albanese        Grayndler       False  \
# 1    187        2         46    John Alexander        Bennelong       False
# 2     52        3         46       Katie Allen          Higgins       False
# 3    110       43         47       Chris Bowen          McMahon       False
# 4    210        9         47      Andrew Bragg  New South Wales        True
# ..   ...      ...        ...               ...              ...         ...
# 207  265       56         46         Ken Wyatt          Hasluck       False
# 208  242      212         47       Terry Young          Longman       False
# 209  230      218         47       Tony Zappia            Makin       False
# 210   63       57         46   Trent Zimmerman     North Sydney       False
# 0     52        3         46               NaN          Higgins       False
#
#      is_representative  graduated       start
# 0                 True       True  1996-03-02  \
# 1                 True       True  2010-08-21
# 2                 True       True  2019-05-18
# 3                 True       True  2010-08-21
# 4                False       True  2019-07-01
# ..                 ...        ...         ...
# 207               True       True  2010-08-21
# 208               True      False  2019-05-18
# 209               True       True  2007-11-24
# 210               True       True  2015-12-05
# 0                 True       True  2019-05-18
#
#                                     wiki_link  ...             high school
# 0      http://www.wikidata.org/entity/Q335697  ...          Non-government  \
# 1      http://www.wikidata.org/entity/Q364407  ...          Non-government
# 2    http://www.wikidata.org/entity/Q38589865  ...          Non-government
# 3     http://www.wikidata.org/entity/Q1077015  ...                  Public
# 4    http://www.wikidata.org/entity/Q64152252  ...          Non-government
# ..                                        ...  ...                     ...
# 207       http://www.wikidata.org/entity/None  ...  Non-government, Public
# 208  http://www.wikidata.org/entity/Q64216512  ...                    None
# 209   http://www.wikidata.org/entity/Q7823721  ...                  Public
# 210  http://www.wikidata.org/entity/Q21680762  ...          Non-government
# 0    http://www.wikidata.org/entity/Q38589865  ...          Non-government
#
#                                          undergraduate
# 0                           BEc (University of Sydney)  \
# 1                                                 None
# 2    MBBS (Monash University), BMedSc (Monash Unive...
# 3                           BEc (University of Sydney)
# 4                  BA (Australian National University)
# ..                                                 ...
# 207    BEd (Churchlands College of Advanced Education)
# 208                                               None
# 209                                               None
# 210                                               None
# 0    MBBS (Monash University), BMedSc (Monash Unive...
#
#                                           postgraduate
# 0                                                 None  \
# 1                                                 None
# 2    PhD (University of Melbourne), FRACP (Royal Au...
# 3                            MIR (Griffith University)
# 4    MFinReg (Macquarie University), MBus (Australi...
# ..                                                 ...
# 207                                               None
# 208                                               None
# 209                                               None
# 210                                               None
# 0    PhD (University of Melbourne), FRACP (Royal Au...
#
#                                                 career        government
# 0                               Business or Management              None  \
# 1                Sports, Business or Management, Media              None
# 2    Science or Engineering, Medicine and Health, N...              None
# 3                                               Unions  Local government
# 4         Business or Management, Lobbying or Activism              None
# ..                                                 ...               ...
# 207  Education, Public Service, Business or Management              None
# 208     Blue-collar or service, Business or Management              None
# 209                             Business or Management  Local government
# 210                               Lobbying or Activism  Local government
# 0    Science or Engineering, Medicine and Health, N...              None
#
#     replied? sex  birth year  member_members   member_smh
# 0        NaN   M        1963             NaN          NaN
# 1        1.0   M        1951             NaN          NaN
# 2        1.0   F        1966             NaN          NaN
# 3        1.0   M        1973             NaN          NaN
# 4        NaN   M        1984             NaN          NaN
# ..       ...  ..         ...             ...          ...
# 207      NaN   M        1952             NaN          NaN
# 208      NaN   M        1968             NaN          NaN
# 209      NaN   M        1952             NaN          NaN
# 210      1.0   M        1968             NaN          NaN
# 0        1.0   F        1966     Katie Allen  Katie Allen
#
# [212 rows x 34 columns]

# %%
# We need to add a member id to members wiki and then use name and wiki link to create new members_education table.
# We can then use this to create a new members_education table

# %%
# first lets also fix members secondary school and check secondary school contains a word
secondary_school = pd.read_sql('''SELECT "PHID", "SecondarySchool" FROM aph_parliamentarians''', engine)
secondary_school["SecondarySchool"] = secondary_school["SecondarySchool"].str.strip()
secondary_school = secondary_school[(secondary_school["SecondarySchool"].notnull()) & (secondary_school["SecondarySchool"].apply(lambda x: len(x)> 0 ) )]
secondary_school.set_index("PHID", inplace=True)
secondary_school["SecondarySchool"] = secondary_school["SecondarySchool"].str.split("/|,", regex=True)

schools = secondary_school.explode("SecondarySchool").reset_index()
schools["SecondarySchool"] = schools["SecondarySchool"].str.strip()
# remove those that are only one word
schools = schools[schools["SecondarySchool"].apply(lambda x: len(x.split(" ")) > 1)]
schools.columns = schools.columns.str.lower()
schools.to_sql("members_secondary_school", engine, if_exists="replace", index=True, index_label="id")
# Out:
# -1

# %%
# now lets add the member id to members wiki
members = pd.read_sql('''SELECT "id", "member", "wiki_link" FROM members''', engine)
null_link = "http://www.wikidata.org/entity/None"
members = members[members["wiki_link"] != null_link]
wiki_members = pd.read_sql('''SELECT id, "member", "wikidata_entity", school_name, school_link from  members_wiki''', engine)
education_links = pd.read_sql('''SELECT "id" as education_id, "school_name", "school_link" FROM education''', engine)
education_links = education_links[(education_links["school_link"].notnull()) & (education_links[education_links["school_link"].notnull()]["school_link"].apply(lambda x: len(x)> 0 )) & (education_links["school_link"] != null_link)]

wiki_merge = pd.merge(members, wiki_members, how="inner", left_on="wiki_link", right_on="wikidata_entity", suffixes=("_members", "_wiki"))
education_merge = pd.merge(wiki_merge, education_links, how="inner", left_on="school_link", right_on="school_link", suffixes=("_wiki", "_education"))
# Todo fix tim wilson now we have fixed his wiki link
# Out:
#         id        member                           wikidata_entity
# 526    527  Frank Timson  http://www.wikidata.org/entity/Q15972597  \
# 527    528  Frank Timson  http://www.wikidata.org/entity/Q15972597
# 1132  1133   Tim Fischer   http://www.wikidata.org/entity/Q7803494
# 1716  1717     Tim Watts  http://www.wikidata.org/entity/Q16222127
# 1720  1721     Tim Watts  http://www.wikidata.org/entity/Q16222127
# 1726  1727     Tim Watts  http://www.wikidata.org/entity/Q16222127
# 1734  1735     Tim Watts  http://www.wikidata.org/entity/Q16222127
# 1834  1835   Tim Hammond  http://www.wikidata.org/entity/Q25856253
# 1835  1836   Tim Hammond  http://www.wikidata.org/entity/Q25856253
# 1860  1861    Tim Wilson  http://www.wikidata.org/entity/Q16205919
# 1862  1863    Tim Wilson  http://www.wikidata.org/entity/Q16205919
# 1864  1865    Tim Wilson  http://www.wikidata.org/entity/Q16205919
# 2920  2921    Tim Storer  http://www.wikidata.org/entity/Q48885543
# 2921  2922    Tim Storer  http://www.wikidata.org/entity/Q48885543
# 2949  2950     Tim Ayres  http://www.wikidata.org/entity/Q64152293
#
#                                            school_name
# 526                           Caulfield Grammar School  \
# 527                                     Wesley College
# 1132                                    Xavier College
# 1716  London School of Economics and Political Science
# 1720                                 Monash University
# 1726                                   Bond University
# 1734               Centenary Heights State High School
# 1834                                Murdoch University
# 1835                   University of Western Australia
# 1860                                 Monash University
# 1862                                Murdoch University
# 1864                                 Peninsula Grammar
# 2920                            University of Adelaide
# 2921                    Australian National University
# 2949                              University of Sydney
#
#                                   school_link
# 526   http://www.wikidata.org/entity/Q5054516
# 527   http://www.wikidata.org/entity/Q7983897
# 1132  http://www.wikidata.org/entity/Q8043217
# 1716   http://www.wikidata.org/entity/Q174570
# 1720   http://www.wikidata.org/entity/Q598841
# 1726   http://www.wikidata.org/entity/Q892188
# 1734  http://www.wikidata.org/entity/Q5059079
# 1834  http://www.wikidata.org/entity/Q1375146
# 1835  http://www.wikidata.org/entity/Q1517021
# 1860   http://www.wikidata.org/entity/Q598841
# 1862  http://www.wikidata.org/entity/Q1375146
# 1864  http://www.wikidata.org/entity/Q7756550
# 2920    http://www.wikidata.org/entity/Q15574
# 2921   http://www.wikidata.org/entity/Q127990
# 2949   http://www.wikidata.org/entity/Q487556

# %%
members[members.member.str.contains("Tim Wilson")]
# Out:
#       id      member                                wiki_link
# 148  159  Tim Wilson  http://www.wikidata.org/entity/Q7807613

# %%
wiki_members[wiki_members.member.str.contains("Tim Wilson")]
# Out:
#         id      member                           wikidata_entity
# 1860  1861  Tim Wilson  http://www.wikidata.org/entity/Q16205919  \
# 1862  1863  Tim Wilson  http://www.wikidata.org/entity/Q16205919
# 1864  1865  Tim Wilson  http://www.wikidata.org/entity/Q16205919
#
#              school_name                              school_link
# 1860   Monash University   http://www.wikidata.org/entity/Q598841
# 1862  Murdoch University  http://www.wikidata.org/entity/Q1375146
# 1864   Peninsula Grammar  http://www.wikidata.org/entity/Q7756550

# %%
education_links[education_links["school_name"].str.contains("Pen")]
# Out:
#      education_id          school_name
# 125            66  Penrith High School  \
# 201           160    Peninsula Grammar
#
#                                  school_link
# 125  http://www.wikidata.org/entity/Q7164606
# 201  http://www.wikidata.org/entity/Q7756550

# %%
education_merge[["id_members", "education_id"]].rename(columns={"id_members": "member_id"}).to_sql("members_education", engine, if_exists="replace", index=True, index_label="id")
# Out:
#        phid                                    secondaryschool
# 0       M3M                         Narrabeen Boys High School
# 1    282986                     Melbourne Girls Grammar School
# 2    282986                                 Albury High School
# 3     13050                              Moorebank High School
# 4     13050                               Meriden Girls School
# ..      ...                                                ...
# 340     E0F                    Ferntree Gully Technical School
# 341     M3A  Corrigin District High School and Hampton Seni...
# 342  201906                          Dakabin State High School
# 343     HWB                                Enfield High School
# 344  203092                                  Newington College
#
# [320 rows x 2 columns]

# %%
education = pd.read_sql('''SELECT education_id, minister_id, school_name, school_link, member, mp_id  FROM education JOIN member_education me on education.id = me.education_id JOIN members m on me.minister_id = m.id''', engine)
all_merged = pd.merge(education, schools, how="inner", left_on="mp_id", right_on="phid", suffixes=("_education", "_secondary_school"))
all_merged
# Out:
#      education_id  minister_id                        school_name
# 0             338          237   Monash University Faculty of Law  \
# 1             335          237                 Murdoch University
# 2             249          237                  Monash University
# 3             129          237       Hollywood Senior High School
# 4             134          280  University of Southern Queensland
# ..            ...          ...                                ...
# 894           248          228      University of South Australia
# 895            24          228   Queechy High School (Launceston)
# 896            24          228   Queechy High School (Launceston)
# 897           301           70            University of Melbourne
# 898           200           70            Lauriston Girls' School
#
#                                  school_link               member   mp_id
# 0    http://www.wikidata.org/entity/Q6898254           Adam Bandt     M3C  \
# 1    http://www.wikidata.org/entity/Q1375146           Adam Bandt     M3C
# 2     http://www.wikidata.org/entity/Q598841           Adam Bandt     M3C
# 3    https://www.wikidata.org/wiki/Q16930409           Adam Bandt     M3C
# 4     http://www.wikidata.org/entity/Q978124  Alexander Gallacher  204953
# ..                                       ...                  ...     ...
# 894    http://www.wikidata.org/entity/Q15576           Zoe Daniel   008CH
# 895                                     None           Zoe Daniel   008CH
# 896                                     None           Zoe Daniel   008CH
# 897   http://www.wikidata.org/entity/Q319078         Zoe McKenzie  124514
# 898  http://www.wikidata.org/entity/Q6501860         Zoe McKenzie  124514
#
#        phid                   secondaryschool
# 0       M3C             Hollywood High School
# 1       M3C             Hollywood High School
# 2       M3C             Hollywood High School
# 3       M3C             Hollywood High School
# 4    204953                Darwin High School
# ..      ...                               ...
# 894   008CH            Rosny College (Hobart)
# 895   008CH  Queechy High School (Launceston)
# 896   008CH            Rosny College (Hobart)
# 897  124514            Lauriston Girls School
# 898  124514            Lauriston Girls School
#
# [899 rows x 8 columns]

# %%
from thefuzz import fuzz

def calc_dist(x):
    if isinstance(x["secondaryschool"], str) and isinstance(x["school_name"], str):
        s1, s2 = x["school_name"], x["secondaryschool"]
        return fuzz.ratio(s1, s2)
    return 0


all_merged["school_name_str_match"] = all_merged.apply(calc_dist, axis=1)
all_merged[all_merged["school_name_str_match"] > 50].sort_values(["school_name_str_match", "secondaryschool"], ascending=False).drop_duplicates(["mp_id", "secondaryschool"], keep="first")
# Out:
#      education_id  minister_id                        school_name
# 834            27           31          York District High School  \
# 127           179          195                     Xavier College
# 214           179            5                     Xavier College
# 123           330          106                  Wyong High School
# 280            22           37                Wynyard High School
# ..            ...          ...                                ...
# 462           290           92                   Canberra College
# 637           133           62             Loreto Mandeville Hall
# 668           102          180  St Joseph's College, Hunters Hill
# 67            119          217             Royal Military College
# 811            77          221         Rockhampton Grammar School
#
#                                   school_link          member   mp_id    phid
# 834                                      None  Tania Lawrence  299150  299150  \
# 127   http://www.wikidata.org/entity/Q8043217    Bill Shorten   00ATG   00ATG
# 214   http://www.wikidata.org/entity/Q8043217       Dan Tehan  210911  210911
# 123                                      None      Ben Morton  265931  265931
# 280    http://www.wikidata.org/entity/Q916063    Gavin Pearce  282306  282306
# ..                                        ...             ...     ...     ...
# 462  http://www.wikidata.org/entity/Q17514127  Katy Gallagher     ING     ING
# 637   http://www.wikidata.org/entity/Q6680935    Monique Ryan  297660  297660
# 668   http://www.wikidata.org/entity/Q3463907    Pat Conaghan  279991  279991
# 67    http://www.wikidata.org/entity/Q2171074   Andrew Wilkie     C2T     C2T
# 811   http://www.wikidata.org/entity/Q7355277   Stuart Robert     HWT     HWT
#
#                secondaryschool  school_name_str_match
# 834  York District High School                    100
# 127             Xavier College                    100
# 214             Xavier College                    100
# 123          Wyong High School                    100
# 280        Wynyard High School                    100
# ..                         ...                    ...
# 462           Stirling College                     56
# 637             Loreto Convent                     56
# 668               Hunters Hill                     53
# 67   McCarthy Catholic College                     51
# 811  Kepnock State High School                     51
#
# [250 rows x 9 columns]

# %%
# check members not in member_education table
members = pd.read_sql('''SELECT * FROM members WHERE id not in (SELECT minister_id from member_education)''', engine)
members
# Out:
#     id  orig_id orig_table          member         district  is_senator
# 0   90      106         47    Karen Grogan  South Australia        True  \
# 1  152      123         47    Llew O'Brien         Wide Bay       False
# 2  175      219         47  Tracey Roberts           Pearce       False
#
#    is_representative  graduated       start
# 0              False       True  2021-09-21  \
# 1               True      False  2016-07-02
# 2               True       True  2022-05-21
#
#                                    wiki_link         dob   mp_id  party_id
# 0  http://www.wikidata.org/entity/Q108617920  1960-01-01  296331        11  \
# 1   http://www.wikidata.org/entity/Q25756234  1972-06-26  265991        42
# 2  http://www.wikidata.org/entity/Q109850050  1960-01-01  157125        11
#
#     house high_school preferred_name            aph_name
# 0  senate        None           None        Karen Grogan
# 1   house        None   Llew O'Brien  Llewellyn  O'Brien
# 2   house        None           None      Tracey Roberts

# %%
# fix and look up correct ids in archive
