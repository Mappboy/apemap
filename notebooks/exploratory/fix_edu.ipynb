# %%
import os

import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv("../../.env")

engine = create_engine(
    f"postgresql+psycopg://{os.environ.get('DATABASE_USERNAME')}:{os.environ.get('DATABASE_PASSWORD')}@localhost:5432/{os.environ.get('DATABASE_NAME')}")

schools_to_fetch = pd.read_sql(
    "SELECT e.* from education e LEFT JOIN education_acara ea on e.id = ea.education_id WHERE acara_id is null AND is_high_school",
    engine)
schools_to_fetch
# Out:
#      id  orig_id    orig_table                         school_name
# 0     1      234     education               Greythorn High School  \
# 1    10       63  education_46                       Padua College
# 2    17       20     education           Emmaus College, Melbourne
# 3    77       47     education          Rockhampton Grammar School
# 4   135      281     education  Victorian School of Correspondence
# 5   161      271     education                St Andrew Muar Johor
# 6   185       31  education_46                  Assumption College
# 7   228       23  education_46                 St Joseph's College
# 8   237       59     education           University Senior College
# 9   270        2     education              Mazenod College, Perth
# 10  278       43  education_46              Belilios Public School
# 11  299       10  education_46           St Mary MacKillop College
# 12  327       80     education                 Enfield High School
# ...

# %%
acara_schools = pd.read_sql(
    '''SELECT * from acara_school_locations_2022 WHERE "school type" in ('Secondary', 'Combined');''', engine)
acara_schools
# Out:
#         fid                                               geom  calendar year
# 0         1  0101000020E6100000516C054D4B5D62407CD289045309...           2022  \
# 1         5  0101000020E610000075745C8DEC5D62408CBCAC890508...           2022
# 2         6  0101000020E610000080EECB99ED5D6240EC1516DC0F08...           2022
# 3         7  0101000020E61000006CEEE87F395D6240F7AE415F7A0B...           2022
# 4        11  0101000020E6100000FAD170CA5C5D62408063CF9ECB0A...           2022
# ...     ...                                                ...            ...
# 4138  10674  0101000020E61000004193ABF531A46240D1ACAE3BC497...           2022
# 4139  10681  0101000020E6100000C286A757CA6A5A403B70CE88D2DE...           2022
# 4140  10682  0101000020E610000030BB270F0B355840C74B37894160...           2022
# 4141  10683  0101000020E610000030BB270F0B355840C74B37894160...           2022
# 4142  10684  0101000020E61000004C7155D9F7FE6440F0A31AF67B0A...           2022
#
# ...

# %%
# This is fixed now
merged = pd.merge(schools_to_fetch, acara_schools, how="inner", left_on=schools_to_fetch.school_name,
                  right_on=acara_schools["school name"], suffixes=(None, "_acara"))
merged.drop_duplicates(subset="school_name", inplace=True, keep=False)
merged[["id", "acara sml id"]].rename({"id": "education_id", "acara sml id": "acara_id"}, axis=1).to_sql(
    "education_acara", engine, if_exists="append", index=False)
# Out:
# 0

# %%
import os

import geopandas as gpd
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv("../../.env")

engine = create_engine(
    f"postgresql+psycopg://{os.environ.get('DATABASE_USERNAME')}:{os.environ.get('DATABASE_PASSWORD')}@localhost:5432/{os.environ.get('DATABASE_NAME')}")

schools_to_fetch = gpd.read_postgis(
    "SELECT e.* from education e LEFT JOIN education_acara ea on e.id = ea.education_id WHERE acara_id is null AND is_high_school",
    engine, geom_col="geometry")
acara_schools = gpd.read_postgis('''SELECT * from acara_school_locations_2022 WHERE "school type" in ('Secondary', 'Combined');''', engine
)
acara_schools = acara_schools.to_crs("EPSG:9473")
schools_to_fetch = schools_to_fetch.to_crs("EPSG:9473")
matched_dist = schools_to_fetch.sjoin_nearest(acara_schools, how="left", max_distance=1000)
matched_dist[matched_dist["acara sml id"].notna()][["id", "acara sml id"]].rename({"id": "education_id", "acara sml id": "acara_id"}, axis=1).to_sql(
    "education_acara", engine, if_exists="append", index=False)
# Out:
# -1

# %%
# Find schools or universities outside australia bounds
pd.read_sql("""SELECT * FROM education where id not in (SELECT id
FROM   education
WHERE  education.geometry
    && -- intersects,  gets more rows  -- CHOOSE ONLY THE
    ST_MakeEnvelope (
        113.338953078, -43.6345972634, -- bounding
        153.569469029, -10.6681857235, -- box limits
        4326))
""", engine)
# Out:
#      id  orig_id    orig_table                               school_name
# 0    13      286     education                   University of Cambridge  \
# 1    49       16  education_46                      Marquette University
# 2    56      151     education  University of Engineering and Technology
# 3   109        3  education_46                 University of East Anglia
# 4   115        1     education                               New College
# 5   122      292     education                      University of Oxford
# 6   127       59  education_46                      University of Dayton
# 7   130       32  education_46                University College, Oxford
# 8   142       19  education_46            Katholieke Universiteit Leuven
# 9   161      271     education                      St Andrew Muar Johor
# 10  175      127     education              London South Bank University
# 11  198      145     education          The American University in Cairo
# ...

# %%
import os

import geopandas as gpd
from dotenv import load_dotenv
from sqlalchemy import create_engine

load_dotenv("../../.env")

engine = create_engine(
    f"postgresql+psycopg://{os.environ.get('DATABASE_USERNAME')}:{os.environ.get('DATABASE_PASSWORD')}@localhost:5432/{os.environ.get('DATABASE_NAME')}")

# Create a copy of existing minister_education table
pd.read_sql("SELECT * FROM minister_education", engine).to_sql("minister_education_copy", engine, if_exists="replace", index=False)

# Remove rows from minister_education where orig_table in education is education_46
pd.read_sql("DELETE FROM minister_education WHERE education_id in ( SELECT id from education where orig_table = 'education_46') ", engine)

# Join education_46 with education using name and join on current minister table using member
pd.read_sql("")
