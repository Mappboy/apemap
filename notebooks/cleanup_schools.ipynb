# %%
import geopandas as gpd
import pathlib
import sqlite3
data_dir = pathlib.Path("..").resolve() / "data"
db_con = sqlite3.connect(str(data_dir / "ppm.sqlite"))
schools = gpd.read_postgis("SELECT * FROM schools;", db_con, geom_col="GEOMETRY")

# %%
schools["GEOMETRY"] = gpd.GeoSeries.from_wkt(schools.location)

# %%
schools =schools.set_crs(epsg=4326)

# %%
import geoalchemy2
# schools.to_postgis("schools", db_con, if_exists="replace", )
schools.to_file(str(data_dir / "ppm.sqlite"), layer='schools', driver="SQLite", if_exists="replace")
schools.to_file(str(data_dir / "ppm.gpkg"), layer='schools', driver="GPKG")

# %%
schools.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95fa9e1e4ef081b115db73e2f577282a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95fa9e1e4ef081b115db73e2f577282a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95fa9e1e4ef081b115db73e2f577282a = L.map(
#                 &quot;map_95fa9e1e4ef081b115db73e2f577282a&quot;,
#                 {
#                     center: [4.3917833349999995, 75.950166665],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_95fa9e1e4ef081b115db73e2f577282a);
#
#
#
#
#
#             var tile_layer_3a158c58c7f536c8b4a5cae476d39dd2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95fa9e1e4ef081b115db73e2f577282a);
#
#
#             map_95fa9e1e4ef081b115db73e2f577282a.fitBounds(
#                 [[-42.9706, -1.25166667], [51.75416667, 153.152]],
#                 {}
#             );
#
#
#         function geo_json_aae7de3bcacfc3a804a521cc85077cd8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_aae7de3bcacfc3a804a521cc85077cd8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_aae7de3bcacfc3a804a521cc85077cd8_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_aae7de3bcacfc3a804a521cc85077cd8_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_aae7de3bcacfc3a804a521cc85077cd8_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_aae7de3bcacfc3a804a521cc85077cd8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_aae7de3bcacfc3a804a521cc85077cd8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_aae7de3bcacfc3a804a521cc85077cd8 = L.geoJson(null, {
#                 onEachFeature: geo_json_aae7de3bcacfc3a804a521cc85077cd8_onEachFeature,
#
#                 style: geo_json_aae7de3bcacfc3a804a521cc85077cd8_styler,
#                 pointToLayer: geo_json_aae7de3bcacfc3a804a521cc85077cd8_pointToLayer
#         });
#
#         function geo_json_aae7de3bcacfc3a804a521cc85077cd8_add (data) {
#             geo_json_aae7de3bcacfc3a804a521cc85077cd8
#                 .addData(data)
#                 .addTo(map_95fa9e1e4ef081b115db73e2f577282a);
#         }
#             geo_json_aae7de3bcacfc3a804a521cc85077cd8_add({&quot;bbox&quot;: [-1.25166667, -42.9706, 153.152, 51.75416667], &quot;features&quot;: [{&quot;bbox&quot;: [-1.25166667, 51.75416667, -1.25166667, 51.75416667], &quot;geometry&quot;: {&quot;coordinates&quot;: [-1.25166667, 51.75416667], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;location&quot;: &quot;Point(-1.25166667 51.75416667)&quot;, &quot;ogc_fid&quot;: 1, &quot;school&quot;: &quot;http://www.wikidata.org/entity/Q1376987&quot;, &quot;schoollabel&quot;: &quot;New College&quot;, &quot;status&quot;: null}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [116.039, -32.0067, 116.039, -32.0067], &quot;g

# %%
missing_school_links = schools[schools["school"].isna()]
missing_school_links.head()
# Out:
#     ogc_fid                     GEOMETRY school  \
# 69       70  POINT (133.86502 -23.70902)   None
# 73       74  POINT (144.98861 -37.78556)   None
# 74       75  POINT (115.76817 -32.06839)   None
# 75       76  POINT (149.09500 -35.32400)   None
# 76       77  POINT (146.33394 -41.16875)   None
#
#                           location                         schoollabel status
# 69    Point(133.865016 -23.709023)           Alice Springs High School   None
# 73    Point(144.988611 -37.785556)                 Fitzroy High School   None
# 74     Point(115.768175 -32.06839)  South Fremantle Senior High School   None
# 75          Point(149.095 -35.324)           Alfred Deakin High School   None
# 76  Point(146.3339412 -41.1687511)         Devonport Technical College   None

# %%
import requests

WIKI_URL = "https://en.wikipedia.org/w/api.php?action=query&prop=pageprops&ppprop=wikibase_item&redirects=1&titles={title}&format=json"

def get_wikipedia_entity_id(title):
    r = requests.get(WIKI_URL.format(title=title))
    r.raise_for_status()
    query = r.json()
    pages = query.get("query", {}).get("pages", {})
    page_ids = pages.keys()
    if page_ids:
        keys = list(page_ids)
        entity_id = pages[keys[0]].get("pageprops", {}).get("wikibase_item")
        if entity_id:
            return f"http://www.wikidata.org/entity/{entity_id}"
# Out:
# 69          http://www.wikidata.org/entity/None
# 73      http://www.wikidata.org/entity/Q5455702
# 74      http://www.wikidata.org/entity/Q7567316
# 75      http://www.wikidata.org/entity/Q4722527
# 76          http://www.wikidata.org/entity/None
# 77      http://www.wikidata.org/entity/Q7595451
# 80      http://www.wikidata.org/entity/Q5377304
# 81          http://www.wikidata.org/entity/None
# 82          http://www.wikidata.org/entity/None
# 83      http://www.wikidata.org/entity/Q7587346
# 84     http://www.wikidata.org/entity/Q24090296
# 85      http://www.wikidata.org/entity/Q1145497
# 86          http://www.wikidata.org/entity/None
# 87      http://www.wikidata.org/entity/Q7824345
# 88      http://www.wikidata.org/entity/Q6704966
# 89      http://www.wikidata.org/entity/Q7271133
# 90      http://www.wikidata.org/entity/Q1202292
# 91      http://www.wikidata.org/entity/Q5209908
# 92          http://www.wikidata.org/entity/None
# 93      http://www.wikidata.org/entity/Q6680935
# 94      http://www.wikidata.org/entity/Q4140009
# 95          http://www.wikidata.org/entity/None
# 96          http://www.wikidata.org/entity/None
# 97          http://www.wikidata.org/entity/None
# 98     http://www.wikidata.org/entity/Q17002256
# 99      http://www.wikidata.org/entity/Q4664329
# 100     http://www.wikidata.org/entity/Q7739309
# 101     http://www.wikidata.org/entity/Q4856538
# 102     http://www.wikidata.org/entity/Q7459149
# 103     http://www.wikidata.org/entity/Q6921839
# 104         http://www.wikidata.org/entity/None
# 105     http://www.wikidata.org/entity/Q3521485
# 106     http://www.wikidata.org/entity/Q7593222
# Name: schoollabel, dtype: object
# 69          http://www.wikidata.org/entity/None
# 73      http://www.wikidata.org/entity/Q5455702
# 74      http://www.wikidata.org/entity/Q7567316
# 75      http://www.wikidata.org/entity/Q4722527
# 76          http://www.wikidata.org/entity/None
# 77      http://www.wikidata.org/entity/Q7595451
# 80      http://www.wikidata.org/entity/Q5377304
# 81          http://www.wikidata.org/entity/None
# 82          http://www.wikidata.org/entity/None
# 83      http://www.wikidata.org/entity/Q7587346
# 84     http://www.wikidata.org/entity/Q24090296
# 85      http://www.wikidata.org/entity/Q1145497
# 86          http://www.wikidata.org/entity/None
# 87      http://www.wikidata.org/entity/Q7824345
# 88      http://www.wikidata.org/entity/Q6704966
# 89      http://www.wikidata.org/entity/Q7271133
# 90      http://www.wikidata.org/entity/Q1202292
# 91      http://www.wikidata.org/entity/Q5209908
# 92          http://www.wikidata.org/entity/None
# 93      http://www.wikidata.org/entity/Q6680935
# 94      http://www.wikidata.org/entity/Q4140009
# 95          http://www.wikidata.org/entity/None
# 96          http://www.wikidata.org/entity/None
# 97          http://www.wikidata.org/entity/None
# 98     http://www.wikidata.org/entity/Q17002256
# 99      http://www.wikidata.org/entity/Q4664329
# 100     http://www.wikidata.org/entity/Q7739309
# 101     http://www.wikidata.org/entity/Q4856538
# 102     http://www.wikidata.org/entity/Q7459149
# 103     http://www.wikidata.org/entity/Q6921839
# 104         http://www.wikidata.org/entity/None
# 105     http://www.wikidata.org/entity/Q3521485
# 106     http://www.wikidata.org/entity/Q7593222
# Name: schoollabel, dtype: object

# %%
s =  missing_school_links.schoollabel.apply(get_wikipedia_entity_id)

# %%
schools.school.fillna(s, inplace=True)

# %%
schools.to_file(str(data_dir / "ppm.sqlite"), layer='schools', driver="SQLite", if_exists="replace")
schools.to_file(str(data_dir / "ppm.gpkg"), layer='schools', driver="GPKG")

# %%
schools.iloc[69]
# Out:
# ogc_fid                                                       70
# GEOMETRY                           POINT (133.865016 -23.709023)
# school         https://www.australianschoolsdirectory.com.au/...
# location                            Point(133.865016 -23.709023)
# schoollabel                            Alice Springs High School
# status                                                      None
# Name: 69, dtype: object

# %%
# Out:
# {'entities': {'Q4722527': {'pageid': 4512807,
#    'ns': 0,
#    'title': 'Q4722527',
#    'lastrevid': 1548876666,
#    'modified': '2021-12-23T17:28:41Z',
#    'type': 'item',
#    'id': 'Q4722527',
#    'labels': {'en': {'language': 'en', 'value': 'Alfred Deakin High School'},
#     'zh-hant': {'language': 'zh-hant', 'value': '阿爾佛雷德迪肯中學'},
#     'zh': {'language': 'zh', 'value': '阿尔弗雷德迪肯中学'}},
#    'descriptions': {'nl': {'language': 'nl',
#      'value': 'high school in Australian Capital Territory, Australië'},
#     'en': {'language': 'en', 'value': 'school in Canberra, Australia'},
#     'de': {'language': 'de', 'value': 'Highschool in Australien'},
#     'ar': {'language': 'ar',
#      'value': 'ثانوية عامة في مقاطعة العاصمة الأسترالية، أستراليا'}},
#    'aliases': {},
#    'claims': {'P625': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P625',
#        'hash': 'd94d0f2a1fa2b22affa2d1e74062c29d2e3161c8',
#        'datavalue': {'value': {'latitude': -35.324,
#          'longitude': 149.095,
#          'altitude': None,
#          'precision': 0.001,
#          'globe': 'http://www.wikidata.org/entity/Q2'},
#         'type': 'globecoordinate'},
#        'datatype': 'globe-coordinate'},
#       'type': 'statement',
#       'id': 'q4722527$9D9A26CE-CF7D-49D6-8DFB-F937AF598C31',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P17': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P17',
#        'hash': '47a4df2f191b139665df3bd52a8081d3e7303b3e',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 408,
#          'id': 'Q408'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q4722527$8647BC26-B05D-46D2-BEC4-7A4A17E9EF0C',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P131': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P131',
#        'hash': '3e1e4b08d2477382dfb31644362ae2db1ccd47d3',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 3258,
#          'id': 'Q3258'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'q4722527$FED5EA0D-D9FD-4D3C-9D28-B751BCB1AE11',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P131',
#        'hash': '51e982e60bcefc889df0712c52a84889b7ae780d',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 671784,
#          'id': 'Q671784'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q4722527$131d4bf5-4285-9c7e-31bf-9d59547c9f76',
#       'rank': 'normal'}],
#     'P31': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P31',
#        'hash': '757a61a40cb8a8569e4fac6ec89d9780484bf60a',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 9826,
#          'id': 'Q9826'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q4722527$58998F45-ABCD-4661-8063-660B949D90D8',
#       'rank': 'normal'},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P31',
#        'hash': '0d11000932244da834c8ea56e636e639cd4fd49b',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 1080794,
#          'id': 'Q1080794'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q4722527$98088908-4735-8f22-0ea2-129ae0fe45a4',
#       'rank': 'normal'}],
#     'P856': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P856',
#        'hash': '34eb2ba855725956f8ae83387e03a9b37f7f4195',
#        'datavalue': {'value': 'http://www.adhs.act.edu.au/', 'type': 'string'},
#        'datatype': 'url'},
#       'type': 'statement',
#       'qualifiers': {'P407': [{'snaktype': 'value',
#          'property': 'P407',
#          'hash': 'b98a5786021620fb0421058635d358dcdfbe6e0f',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 44679,
#            'id': 'Q44679'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P407'],
#       'id': 'Q4722527$44C6EAF0-4038-404A-B228-3FAB9FD239D1',
#       'rank': 'normal',
#       'references': [{'hash': '8b7f3668b22e0f272d61ac5b72b276d65a5ce7a3',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'ec949f262942cea550e35e0985d1169226f56b90',
#            'datavalue': {'value': 'https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2019d55613404c94637ead88ff00003e0139.xlsx?sfvrsn=7cc27007_0',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P3417': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P3417',
#        'hash': '76d35a72806c4e14cdab53b7019fa1e3e7d6e0b5',
#        'datavalue': {'value': 'Alfred-Deakin-High-School', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q4722527$1F5D365E-AB9E-4147-B86F-6A94FCBCAC62',
#       'rank': 'normal',
#       'references': [{'hash': '3b0a5bb3c1f955edce73740124f7d935698092ad',
#         'snaks': {'P248': [{'snaktype': 'value',
#            'property': 'P248',
#            'hash': '3ac9682e789a3a3791d4fd088b265ea03abef101',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 51711,
#              'id': 'Q51711'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P248']}]}],
#     'P138': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P138',
#        'hash': '5c5d25d9e8c185bf3e2ffffda5b1dd6f4a6db568',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 313805,
#          'id': 'Q313805'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q4722527$8626fce6-4426-3afc-267d-96cbff8efda1',
#       'rank': 'normal'}],
#     'P571': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P571',
#        'hash': '551a6d572e2d55fa1aefb8d5f9e7464617fa78f5',
#        'datavalue': {'value': {'time': '+1989-00-00T00:00:00Z',
#          'timezone': 0,
#          'before': 0,
#          'after': 0,
#          'precision': 9,
#          'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#         'type': 'time'},
#        'datatype': 'time'},
#       'type': 'statement',
#       'id': 'Q4722527$A7CCDEF7-61D3-4F1C-BDEA-D8F55045C72A',
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'snaktype': 'value',
#            'property': 'P143',
#            'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 328,
#              'id': 'Q328'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'snaks-order': ['P143']}]}],
#     'P5245': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P5245',
#        'hash': 'b6b2beff126316d0a745a929f8d2c4188b113486',
#        'datavalue': {'value': '49911', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q4722527$8CC1D5B1-73E8-4AB2-8A5F-2166ACF3B4EE',
#       'rank': 'normal'}],
#     'P2196': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P2196',
#        'hash': 'a64c91c85b908a5853b3ef45f220a427299c4fcc',
#        'datavalue': {'value': {'amount': '+898', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': 'c34a8cfb745b0cda47dffa6967839b8f92bcb653',
#          'datavalue': {'value': {'time': '+2017-00-00T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 9,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P585'],
#       'id': 'Q4722527$6e205f02-470c-7853-9a45-7934b6295fff',
#       'rank': 'normal'},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P2196',
#        'hash': '10aed750c3e37dfd3324a6ee981ff8459f8ca064',
#        'datavalue': {'value': {'amount': '+394', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '9a8fd19dd6b82320a466b8cffbaeed09fbc1622c',
#          'datavalue': {'value': {'time': '+2019-01-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 9,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P518': [{'snaktype': 'value',
#          'property': 'P518',
#          'hash': '9cdf8a85bc4fdd14cc2298f24adcae0e5a262faa',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 3031,
#            'id': 'Q3031'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P585', 'P518'],
#       'id': 'Q4722527$CD065517-9564-4599-95AF-543564FA7A85',
#       'rank': 'normal',
#       'references': [{'hash': '41b9f6b333111133bf74d7582c41f297e394e9da',
#         'snaks': {'P123': [{'snaktype': 'value',
#            'property': 'P123',
#            'hash': '58dbc95c614d2b2cda90b3449f4f231a87fa4ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4824057,
#              'id': 'Q4824057'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'ec949f262942cea550e35e0985d1169226f56b90',
#            'datavalue': {'value': 'https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2019d55613404c94637ead88ff00003e0139.xlsx?sfvrsn=7cc27007_0',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P123', 'P854']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P2196',
#        'hash': '834a1273eded80311f47b2c4fc07757c885859f7',
#        'datavalue': {'value': {'amount': '+472', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P518': [{'snaktype': 'value',
#          'property': 'P518',
#          'hash': '35a92456a7b3e0b94de783ff20c72749c0ec5839',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 3010,
#            'id': 'Q3010'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '9a8fd19dd6b82320a466b8cffbaeed09fbc1622c',
#          'datavalue': {'value': {'time': '+2019-01-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 9,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P518', 'P585'],
#       'id': 'Q4722527$C1F58BD2-B1BB-41C9-965C-AFADB9C040F8',
#       'rank': 'normal',
#       'references': [{'hash': '41b9f6b333111133bf74d7582c41f297e394e9da',
#         'snaks': {'P123': [{'snaktype': 'value',
#            'property': 'P123',
#            'hash': '58dbc95c614d2b2cda90b3449f4f231a87fa4ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4824057,
#              'id': 'Q4824057'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'ec949f262942cea550e35e0985d1169226f56b90',
#            'datavalue': {'value': 'https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2019d55613404c94637ead88ff00003e0139.xlsx?sfvrsn=7cc27007_0',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P123', 'P854']}]}],
#     'P281': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P281',
#        'hash': '9c3a21eea924f45fda88b80b0e481fb3f5999e26',
#        'datavalue': {'value': '2600', 'type': 'string'},
#        'datatype': 'string'},
#       'type': 'statement',
#       'id': 'Q4722527$A5E8BD0A-3A96-4E29-AF5A-944EF4393CFC',
#       'rank': 'normal',
#       'references': [{'hash': '41b9f6b333111133bf74d7582c41f297e394e9da',
#         'snaks': {'P123': [{'snaktype': 'value',
#            'property': 'P123',
#            'hash': '58dbc95c614d2b2cda90b3449f4f231a87fa4ecd',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 4824057,
#              'id': 'Q4824057'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'ec949f262942cea550e35e0985d1169226f56b90',
#            'datavalue': {'value': 'https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2019d55613404c94637ead88ff00003e0139.xlsx?sfvrsn=7cc27007_0',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P123', 'P854']}]}],
#     'P1128': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P1128',
#        'hash': '1869dd656809b281a0b387433fa7aab7f6428c9c',
#        'datavalue': {'value': {'amount': '+66', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '9a8fd19dd6b82320a466b8cffbaeed09fbc1622c',
#          'datavalue': {'value': {'time': '+2019-01-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 9,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}],
#        'P518': [{'snaktype': 'value',
#          'property': 'P518',
#          'hash': '7fa6e46bcdf60f15e62c5aea558fcba56e3e7748',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 37226,
#            'id': 'Q37226'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}]},
#       'qualifiers-order': ['P585', 'P518'],
#       'id': 'Q4722527$268760FE-1E32-4871-8422-EA75851CDD25',
#       'rank': 'normal',
#       'references': [{'hash': '8b7f3668b22e0f272d61ac5b72b276d65a5ce7a3',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'ec949f262942cea550e35e0985d1169226f56b90',
#            'datavalue': {'value': 'https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2019d55613404c94637ead88ff00003e0139.xlsx?sfvrsn=7cc27007_0',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]},
#      {'mainsnak': {'snaktype': 'value',
#        'property': 'P1128',
#        'hash': 'eb1d45c5ed141f8adc3306bf3a1f9c741a3f8452',
#        'datavalue': {'value': {'amount': '+20', 'unit': '1'},
#         'type': 'quantity'},
#        'datatype': 'quantity'},
#       'type': 'statement',
#       'qualifiers': {'P1011': [{'snaktype': 'value',
#          'property': 'P1011',
#          'hash': '1ab296efa952fc33044f5652d656cd03a2045cf4',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 37226,
#            'id': 'Q37226'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'}],
#        'P585': [{'snaktype': 'value',
#          'property': 'P585',
#          'hash': '9a8fd19dd6b82320a466b8cffbaeed09fbc1622c',
#          'datavalue': {'value': {'time': '+2019-01-01T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 9,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'}]},
#       'qualifiers-order': ['P1011', 'P585'],
#       'id': 'Q4722527$39061D72-FB0A-4C1A-962D-3840A8FE233E',
#       'rank': 'normal',
#       'references': [{'hash': '8b7f3668b22e0f272d61ac5b72b276d65a5ce7a3',
#         'snaks': {'P854': [{'snaktype': 'value',
#            'property': 'P854',
#            'hash': 'ec949f262942cea550e35e0985d1169226f56b90',
#            'datavalue': {'value': 'https://www.acara.edu.au/docs/default-source/default-document-library/school-profile-2019d55613404c94637ead88ff00003e0139.xlsx?sfvrsn=7cc27007_0',
#             'type': 'string'},
#            'datatype': 'url'}]},
#         'snaks-order': ['P854']}]}],
#     'P646': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P646',
#        'hash': '87cb795cec106e1b59daad0b966e39be2d674da6',
#        'datavalue': {'value': '/m/03qc9kp', 'type': 'string'},
#        'datatype': 'external-id'},
#       'type': 'statement',
#       'id': 'Q4722527$4783BEE3-F8C9-478E-B0C4-17D7C6A0AECB',
#       'rank': 'normal'}],
#     'P749': [{'mainsnak': {'snaktype': 'value',
#        'property': 'P749',
#        'hash': '9a893a24f972eed19e6f8661194c024b6f6d0cfc',
#        'datavalue': {'value': {'entity-type': 'item',
#          'numeric-id': 110248228,
#          'id': 'Q110248228'},
#         'type': 'wikibase-entityid'},
#        'datatype': 'wikibase-item'},
#       'type': 'statement',
#       'id': 'Q4722527$b529e47a-4911-a801-1378-b74aff0e4783',
#       'rank': 'normal'}]},
#    'sitelinks': {'enwiki': {'site': 'enwiki',
#      'title': 'Alfred Deakin High School',
#      'badges': []}}}},
#  'success': 1}
